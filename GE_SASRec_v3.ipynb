# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %matplotlib inline

# %%
# !python /content/drive/MyDrive/GES/main.py --dataset Amazon
# Out:
# {'dataset': 'Amazon', 'num_factor': 64, 'lr': 0.001, 'l2_reg': 0, 'batch_size': 256, 'num_epoch': 200, 'max_len': 50, 'num_block': 1, 'num_head': 1, 'emb_dropout_rate': 0.1, 'node_dropout_rate': 0.1, 'random_seed': 2021, 'gnn': 'sgc', 'num_layer': 1, 'alpha': 1.0, 'beta': 1.0, 'layer_agg': 'none'}
# num_user:27738, num_item:43790
# max len: 407, min len:8, avg len:20.52
# Model preparing...
# model preparing...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# ...

# %%
# !python /content/drive/MyDrive/GES/main.py --dataset Google
# Out:
# {'dataset': 'Google', 'num_factor': 64, 'lr': 0.001, 'l2_reg': 0, 'batch_size': 256, 'num_epoch': 200, 'max_len': 50, 'num_block': 1, 'num_head': 1, 'emb_dropout_rate': 0.1, 'node_dropout_rate': 0.1, 'random_seed': 2021, 'gnn': 'sgc', 'num_layer': 1, 'alpha': 1.0, 'beta': 1.0, 'layer_agg': 'none'}
# num_user:16381, num_item:34928
# max len: 608, min len:8, avg len:24.12
# Model preparing...
# model preparing...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# ...

# %%
# !python /content/drive/MyDrive/GES/main.py --dataset Yelp
# Out:
# {'dataset': 'Yelp', 'num_factor': 64, 'lr': 0.001, 'l2_reg': 0, 'batch_size': 256, 'num_epoch': 200, 'max_len': 50, 'num_block': 1, 'num_head': 1, 'emb_dropout_rate': 0.1, 'node_dropout_rate': 0.1, 'random_seed': 2021, 'gnn': 'sgc', 'num_layer': 1, 'alpha': 1.0, 'beta': 1.0, 'layer_agg': 'none'}
# num_user:32206, num_item:27671
# max len: 478, min len:8, avg len:20.55
# Model preparing...
# model preparing...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# ...

# %%
# !python /content/drive/MyDrive/GES/main.py --dataset Amazon --num_factor 128
# Out:
# {'dataset': 'Amazon', 'num_factor': 128, 'lr': 0.001, 'l2_reg': 0, 'batch_size': 256, 'num_epoch': 200, 'max_len': 50, 'num_block': 1, 'num_head': 1, 'emb_dropout_rate': 0.1, 'node_dropout_rate': 0.1, 'random_seed': 2021, 'gnn': 'sgc', 'num_layer': 1, 'alpha': 1.0, 'beta': 1.0, 'layer_agg': 'none'}
# num_user:27738, num_item:43790
# max len: 407, min len:8, avg len:20.52
# Model preparing...
# model preparing...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# ...

# %%
# !python /content/drive/MyDrive/GES/main.py --dataset Google --num_factor 128
# Out:
# {'dataset': 'Google', 'num_factor': 128, 'lr': 0.001, 'l2_reg': 0, 'batch_size': 256, 'num_epoch': 200, 'max_len': 50, 'num_block': 1, 'num_head': 1, 'emb_dropout_rate': 0.1, 'node_dropout_rate': 0.1, 'random_seed': 2021, 'gnn': 'sgc', 'num_layer': 1, 'alpha': 1.0, 'beta': 1.0, 'layer_agg': 'none'}
# num_user:16381, num_item:34928
# max len: 608, min len:8, avg len:24.12
# Model preparing...
# model preparing...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# ...

# %%
# !python /content/drive/MyDrive/GES/main.py --dataset Yelp --num_factor 128
# Out:
# {'dataset': 'Yelp', 'num_factor': 128, 'lr': 0.001, 'l2_reg': 0, 'batch_size': 256, 'num_epoch': 200, 'max_len': 50, 'num_block': 1, 'num_head': 1, 'emb_dropout_rate': 0.1, 'node_dropout_rate': 0.1, 'random_seed': 2021, 'gnn': 'sgc', 'num_layer': 1, 'alpha': 1.0, 'beta': 1.0, 'layer_agg': 'none'}
# num_user:32206, num_item:27671
# max len: 478, min len:8, avg len:20.55
# Model preparing...
# model preparing...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# ...

# %%
# %run /content/drive/MyDrive/GES/main.py --dataset Amazon --num_factor 256 --num_epoch 100
# Out:
# {'dataset': 'Amazon', 'num_factor': 256, 'lr': 0.001, 'l2_reg': 0, 'batch_size': 256, 'num_epoch': 100, 'max_len': 50, 'num_block': 1, 'num_head': 1, 'emb_dropout_rate': 0.1, 'node_dropout_rate': 0.1, 'random_seed': 2021, 'gnn': 'sgc', 'num_layer': 1, 'alpha': 1.0, 'beta': 1.0, 'layer_agg': 'none'}
# num_user:27738, num_item:43790
# max len: 407, min len:8, avg len:20.52
# Model preparing...
# model preparing...
# Model training...
# epoch: 1, 31.91s
# training loss: 0.8562
# HR@10: 0.3345, NDCG@10: 0.1812, MRR@10: 0.1347
# epoch: 2, 31.21s
# training loss: 0.5907
# HR@10: 0.4005, NDCG@10: 0.2235, MRR@10: 0.1695
# epoch: 3, 32.88s
# training loss: 0.5177
# HR@10: 0.4381, NDCG@10: 0.2486, MRR@10: 0.1907
# epoch: 4, 31.22s
# training loss: 0.4728
# HR@10: 0.4589, NDCG@10: 0.2634, MRR@10: 0.2036
# epoch: 5, 31.13s
# training loss: 0.4367
# HR@10: 0.4873, NDCG@10: 0.2863, MRR@10: 0.2247
# epoch: 6, 31.32s
# training loss: 0.4112
# HR@10: 0.4960, NDCG@10: 0.2930, MRR@10: 0.2307
# ...

# %%
# %run /content/drive/MyDrive/GES/main.py --dataset Google --num_factor 256
# Out:
# {'dataset': 'Google', 'num_factor': 256, 'lr': 0.001, 'l2_reg': 0, 'batch_size': 256, 'num_epoch': 200, 'max_len': 50, 'num_block': 1, 'num_head': 1, 'emb_dropout_rate': 0.1, 'node_dropout_rate': 0.1, 'random_seed': 2021, 'gnn': 'sgc', 'num_layer': 1, 'alpha': 1.0, 'beta': 1.0, 'layer_agg': 'none'}
# num_user:16381, num_item:34928
# max len: 608, min len:8, avg len:24.12
# Model preparing...
# model preparing...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# ...

# %%
# %run /content/drive/MyDrive/GES/main.py --dataset Yelp --num_factor 256
# Out:
# {'dataset': 'Yelp', 'num_factor': 256, 'lr': 0.001, 'l2_reg': 0, 'batch_size': 256, 'num_epoch': 200, 'max_len': 50, 'num_block': 1, 'num_head': 1, 'emb_dropout_rate': 0.1, 'node_dropout_rate': 0.1, 'random_seed': 2021, 'gnn': 'sgc', 'num_layer': 1, 'alpha': 1.0, 'beta': 1.0, 'layer_agg': 'none'}
# num_user:32206, num_item:27671
# max len: 478, min len:8, avg len:20.55
# Model preparing...
# model preparing...
# Model training...
# epoch: 1, 29.50s
# training loss: 0.7372
# HR@10: 0.2814, NDCG@10: 0.1520, MRR@10: 0.1128
# epoch: 2, 27.47s
# training loss: 0.5392
# HR@10: 0.3019, NDCG@10: 0.1637, MRR@10: 0.1218
# epoch: 3, 27.46s
# training loss: 0.5047
# HR@10: 0.3238, NDCG@10: 0.1761, MRR@10: 0.1313
# epoch: 4, 27.82s
# training loss: 0.4827
# HR@10: 0.3358, NDCG@10: 0.1832, MRR@10: 0.1369
# epoch: 5, 27.22s
# training loss: 0.4672
# HR@10: 0.3443, NDCG@10: 0.1880, MRR@10: 0.1405
# epoch: 6, 32.75s
# training loss: 0.4567
# HR@10: 0.3515, NDCG@10: 0.1921, MRR@10: 0.1437
# ...
